# %%
#IMPORTING LIBRARIES
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import numpy as np

#IMPORTING DATASET
df = pd.read_csv('breastcancer.csv')
df
# Out:
#                  id diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0      8.423020e+05         M    17.990000     10.380000      122.800000
# 1      8.425170e+05         M    20.570000     17.770000      132.900000
# 2      8.430090e+07         M    19.690000     21.250000      130.000000
# 3      8.434830e+07         M    11.420000     20.380000       77.580000
# 4      8.435840e+07         M    20.290000     14.340000      135.100000
# ...             ...       ...          ...           ...             ...
# 10564  8.912055e+06         B    11.760441     14.005757       74.236872
# 10565  8.445820e+07         M    13.706025     20.844266       90.230893
# 10566  8.691041e+05         M    16.099009     18.075081      105.085316
# 10567  9.112962e+08         M    17.064702     27.148552      111.232523
# 10568  8.917030e+05         B    11.832701     17.472489       75.549041
#
#          area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0      1001.000000         0.118400          0.277600        0.300100
# 1      1326.000000         0.084740          0.078640        0.086900
# 2      1203.000000         0.109600          0.159900        0.197400
# 3       386.100000         0.142500          0.283900        0.241400
# 4      1297.000000         0.100300          0.132800        0.198000
# ...            ...              ...               ...             ...
# 10564   427.301531         0.091204          0.069957        0.024872
# 10565   577.896989         0.145517          0.168273        0.093299
# 10566   813.001891         0.085776          0.102347        0.081731
# 10567   930.908894         0.093984          0.119383        0.117841
# 10568   432.719302         0.069454          0.085861        0.036284
#
#        concave points_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0                 0.147100  ...     25.380000      17.330000       184.600000
# 1                 0.070170  ...     24.990000      23.410000       158.800000
# 2                 0.127900  ...     23.570000      25.530000       152.500000
# 3                 0.105200  ...     14.910000      26.500000        98.870000
# 4                 0.104300  ...     22.540000      16.670000       152.200000
# ...                    ...  ...           ...            ...              ...
# 10564             0.043946  ...     13.283847      18.293434        84.709503
# 10565             0.081679  ...     17.090649      28.161669       110.570309
# 10566             0.121835  ...     19.941688      25.303457       129.007313
# 10567             0.081529  ...     22.952756      34.442142       152.119780
# 10568             0.030022  ...     13.058448      25.781170        84.372807
#
#         area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.000000          0.162200           0.665600         0.711900
# 1      1956.000000          0.123800           0.186600         0.241600
# 2      1709.000000          0.144400           0.424500         0.450400
# 3       567.700000          0.209800           0.866300         0.686900
# 4      1575.000000          0.137400           0.205000         0.400000
# ...            ...               ...                ...              ...
# 10564   533.704490          0.119710           0.120541         0.074352
# 10565   897.005786          0.189149           0.363931         0.269874
# 10566  1233.007009          0.102405           0.199145         0.252063
# 10567  1648.030631          0.167075           0.254909         0.242346
# 10568   517.829866          0.142929           0.207678         0.130731
#
#        concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                  0.265400        0.460100                 0.118900
# 1                  0.186000        0.275000                 0.089020
# 2                  0.243000        0.361300                 0.087580
# 3                  0.257500        0.663800                 0.173000
# 4                  0.162500        0.236400                 0.076780
# ...                     ...             ...                      ...
# 10564              0.094832        0.316553                 0.067760
# 10565              0.128229        0.368549                 0.104436
# 10566              0.148563        0.245300                 0.088031
# 10567              0.172600        0.317086                 0.080016
# 10568              0.081839        0.314089                 0.082594
#
# [10569 rows x 32 columns]

# %%
# SHAPE OF THE DATASET
df.shape
# Out:
# (10569, 32)

# %%
# INFORMATION ABOUT THE DATASET
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10569 entries, 0 to 10568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       10569 non-null  float64
#  1   diagnosis                10569 non-null  object
#  2   radius_mean              10569 non-null  float64
#  3   texture_mean             10569 non-null  float64
#  4   perimeter_mean           10569 non-null  float64
#  5   area_mean                10569 non-null  float64
#  6   smoothness_mean          10569 non-null  float64
#  7   compactness_mean         10569 non-null  float64
#  8   concavity_mean           10569 non-null  float64
#  9   concave points_mean      10569 non-null  float64
#  10  symmetry_mean            10569 non-null  float64
#  11  fractal_dimension_mean   10569 non-null  float64
#  12  radius_se                10569 non-null  float64
#  13  texture_se               10569 non-null  float64
#  14  perimeter_se             10569 non-null  float64
#  15  area_se                  10569 non-null  float64
#  16  smoothness_se            10569 non-null  float64
#  17  compactness_se           10569 non-null  float64
#  18  concavity_se             10569 non-null  float64
#  19  concave points_se        10569 non-null  float64
#  20  symmetry_se              10569 non-null  float64
#  21  fractal_dimension_se     10569 non-null  float64
#  22  radius_worst             10569 non-null  float64
#  23  texture_worst            10569 non-null  float64
#  24  perimeter_worst          10569 non-null  float64
#  25  area_worst               10569 non-null  float64
#  26  smoothness_worst         10569 non-null  float64
#  27  compactness_worst        10569 non-null  float64
#  28  concavity_worst          10569 non-null  float64
#  29  concave points_worst     10569 non-null  float64
#  30  symmetry_worst           10569 non-null  float64
#  31  fractal_dimension_worst  10569 non-null  float64
# dtypes: float64(31), object(1)
# memory usage: 2.6+ MB

# %%
# TOP 5 ROWS
df.head()
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302.0         M        17.99         10.38          122.80     1001.0
# 1    842517.0         M        20.57         17.77          132.90     1326.0
# 2  84300903.0         M        19.69         21.25          130.00     1203.0
# 3  84348301.0         M        11.42         20.38           77.58      386.1
# 4  84358402.0         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0  ...         25.38          17.33           184.60      2019.0
# 1  ...         24.99          23.41           158.80      1956.0
# 2  ...         23.57          25.53           152.50      1709.0
# 3  ...         14.91          26.50            98.87       567.7
# 4  ...         22.54          16.67           152.20      1575.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    symmetry_worst  fractal_dimension_worst
# 0          0.4601                  0.11890
# 1          0.2750                  0.08902
# 2          0.3613                  0.08758
# 3          0.6638                  0.17300
# 4          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %%
# BOTTOM 5 ROWS
df.tail()
# Out:
#                  id diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 10564  8.912055e+06         B    11.760441     14.005757       74.236872
# 10565  8.445820e+07         M    13.706025     20.844266       90.230893
# 10566  8.691041e+05         M    16.099009     18.075081      105.085316
# 10567  9.112962e+08         M    17.064702     27.148552      111.232523
# 10568  8.917030e+05         B    11.832701     17.472489       75.549041
#
#         area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 10564  427.301531         0.091204          0.069957        0.024872
# 10565  577.896989         0.145517          0.168273        0.093299
# 10566  813.001891         0.085776          0.102347        0.081731
# 10567  930.908894         0.093984          0.119383        0.117841
# 10568  432.719302         0.069454          0.085861        0.036284
#
#        concave points_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 10564             0.043946  ...     13.283847      18.293434        84.709503
# 10565             0.081679  ...     17.090649      28.161669       110.570309
# 10566             0.121835  ...     19.941688      25.303457       129.007313
# 10567             0.081529  ...     22.952756      34.442142       152.119780
# 10568             0.030022  ...     13.058448      25.781170        84.372807
#
#         area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 10564   533.704490          0.119710           0.120541         0.074352
# 10565   897.005786          0.189149           0.363931         0.269874
# 10566  1233.007009          0.102405           0.199145         0.252063
# 10567  1648.030631          0.167075           0.254909         0.242346
# 10568   517.829866          0.142929           0.207678         0.130731
#
#        concave points_worst  symmetry_worst  fractal_dimension_worst
# 10564              0.094832        0.316553                 0.067760
# 10565              0.128229        0.368549                 0.104436
# 10566              0.148563        0.245300                 0.088031
# 10567              0.172600        0.317086                 0.080016
# 10568              0.081839        0.314089                 0.082594
#
# [5 rows x 32 columns]

# %%
# DESCRIPTION OF  DATASET
df.describe()
# Out:
#                  id   radius_mean  texture_mean  perimeter_mean     area_mean  \
# count  1.056900e+04  10569.000000  10569.000000    10569.000000  10569.000000
# mean   3.003263e+07     14.173051     19.268158       92.266945    658.918849
# std    1.249955e+08      3.532367      4.339769       24.338030    352.247874
# min    8.669972e+03      6.956460      9.667446       43.766537    143.446908
# 25%    8.692540e+05     11.719248     16.153492       75.444325    420.992124
# 50%    9.059780e+05     13.403672     18.780661       86.507673    552.435459
# 75%    8.812844e+06     16.025201     21.729073      105.085824    793.202269
# max    9.113205e+08     28.167247     39.345325      188.527748   2501.039752
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count     10569.000000      10569.000000    10569.000000         10569.000000
# mean          0.096056          0.104380        0.089455             0.049292
# std           0.024084          0.056097        0.082215             0.043201
# min          -0.001558         -0.044590       -0.060165            -0.059224
# 25%           0.079782          0.064038        0.029572             0.018336
# 50%           0.095970          0.095928        0.066274             0.041028
# 75%           0.112100          0.133396        0.131670             0.075239
# max           0.208199          0.394370        0.477638             0.230738
#
#        symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# count   10569.000000  ...  10569.000000   10569.000000     10569.000000
# mean        0.180671  ...     16.311604      25.652948       107.483504
# std         0.033254  ...      4.830401       6.187516        33.531005
# min         0.079608  ...      7.892828      12.000222        50.374109
# 25%         0.158199  ...     13.049847      21.014106        84.448938
# 50%         0.179219  ...     14.987433      25.273021        97.914423
# 75%         0.200575  ...     18.868252      29.660000       126.291408
# max         0.327646  ...     36.061771      49.575609       251.233126
#
#          area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# count  10569.000000      10569.000000       10569.000000     10569.000000
# mean     884.458819          0.132364           0.253911         0.272491
# std      568.367839          0.029263           0.155898         0.208131
# min      185.159411          0.021446          -0.039429        -0.056511
# 25%      516.496222          0.112192           0.144555         0.116298
# 50%      688.585016          0.131691           0.217194         0.228897
# 75%     1088.033273          0.151516           0.333786         0.382747
# max     4254.027472          0.257891           1.111206         1.290478
#
#        concave points_worst  symmetry_worst  fractal_dimension_worst
# count          10569.000000    10569.000000             10569.000000
# mean               0.115045        0.290038                 0.083883
# std                0.068223        0.064972                 0.026091
# min               -0.071471        0.116273                 0.002225
# 25%                0.063817        0.247737                 0.066390
# 50%                0.102968        0.282562                 0.082275
# 75%                0.163712        0.320346                 0.099460
# max                0.331218        0.732077                 0.234308
#
# [8 rows x 31 columns]

# %%
# CHECKING NULL VALUES
df.isnull().sum()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %%
# DROPPING
df.dropna(inplace = True)

# %%
#DROPPING ID COLOUMN
df.drop('id',axis = 1,inplace = True)
df
# Out:
#       diagnosis  radius_mean  texture_mean  perimeter_mean    area_mean  \
# 0             M    17.990000     10.380000      122.800000  1001.000000
# 1             M    20.570000     17.770000      132.900000  1326.000000
# 2             M    19.690000     21.250000      130.000000  1203.000000
# 3             M    11.420000     20.380000       77.580000   386.100000
# 4             M    20.290000     14.340000      135.100000  1297.000000
# ...         ...          ...           ...             ...          ...
# 10564         B    11.760441     14.005757       74.236872   427.301531
# 10565         M    13.706025     20.844266       90.230893   577.896989
# 10566         M    16.099009     18.075081      105.085316   813.001891
# 10567         M    17.064702     27.148552      111.232523   930.908894
# 10568         B    11.832701     17.472489       75.549041   432.719302
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0             0.118400          0.277600        0.300100             0.147100
# 1             0.084740          0.078640        0.086900             0.070170
# 2             0.109600          0.159900        0.197400             0.127900
# 3             0.142500          0.283900        0.241400             0.105200
# 4             0.100300          0.132800        0.198000             0.104300
# ...                ...               ...             ...                  ...
# 10564         0.091204          0.069957        0.024872             0.043946
# 10565         0.145517          0.168273        0.093299             0.081679
# 10566         0.085776          0.102347        0.081731             0.121835
# 10567         0.093984          0.119383        0.117841             0.081529
# 10568         0.069454          0.085861        0.036284             0.030022
#
#        symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0           0.241900  ...     25.380000      17.330000       184.600000
# 1           0.181200  ...     24.990000      23.410000       158.800000
# 2           0.206900  ...     23.570000      25.530000       152.500000
# 3           0.259700  ...     14.910000      26.500000        98.870000
# 4           0.180900  ...     22.540000      16.670000       152.200000
# ...              ...  ...           ...            ...              ...
# 10564       0.226635  ...     13.283847      18.293434        84.709503
# 10565       0.202809  ...     17.090649      28.161669       110.570309
# 10566       0.189788  ...     19.941688      25.303457       129.007313
# 10567       0.193640  ...     22.952756      34.442142       152.119780
# 10568       0.192502  ...     13.058448      25.781170        84.372807
#
#         area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.000000          0.162200           0.665600         0.711900
# 1      1956.000000          0.123800           0.186600         0.241600
# 2      1709.000000          0.144400           0.424500         0.450400
# 3       567.700000          0.209800           0.866300         0.686900
# 4      1575.000000          0.137400           0.205000         0.400000
# ...            ...               ...                ...              ...
# 10564   533.704490          0.119710           0.120541         0.074352
# 10565   897.005786          0.189149           0.363931         0.269874
# 10566  1233.007009          0.102405           0.199145         0.252063
# 10567  1648.030631          0.167075           0.254909         0.242346
# 10568   517.829866          0.142929           0.207678         0.130731
#
#        concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                  0.265400        0.460100                 0.118900
# 1                  0.186000        0.275000                 0.089020
# 2                  0.243000        0.361300                 0.087580
# 3                  0.257500        0.663800                 0.173000
# 4                  0.162500        0.236400                 0.076780
# ...                     ...             ...                      ...
# 10564              0.094832        0.316553                 0.067760
# 10565              0.128229        0.368549                 0.104436
# 10566              0.148563        0.245300                 0.088031
# 10567              0.172600        0.317086                 0.080016
# 10568              0.081839        0.314089                 0.082594
#
# [10569 rows x 31 columns]

# %%
# CHECKING DUPLICATES
df.duplicated().sum()
# Out:
# 0

# %%
# DROPPING DUPLICATE VALUES
df.drop_duplicates(inplace = True)

# %%
# FINDING UNIQUE VALUES
df['diagnosis'].unique()
# Out:
# array(['M', 'B'], dtype=object)

# %%
# MAPPING STRING VALUES TO INTEGER
df['diagnosis'] = df['diagnosis'].map({'M':0,'B':1})
df
# Out:
#        diagnosis  radius_mean  texture_mean  perimeter_mean    area_mean  \
# 0              0    17.990000     10.380000      122.800000  1001.000000
# 1              0    20.570000     17.770000      132.900000  1326.000000
# 2              0    19.690000     21.250000      130.000000  1203.000000
# 3              0    11.420000     20.380000       77.580000   386.100000
# 4              0    20.290000     14.340000      135.100000  1297.000000
# ...          ...          ...           ...             ...          ...
# 10564          1    11.760441     14.005757       74.236872   427.301531
# 10565          0    13.706025     20.844266       90.230893   577.896989
# 10566          0    16.099009     18.075081      105.085316   813.001891
# 10567          0    17.064702     27.148552      111.232523   930.908894
# 10568          1    11.832701     17.472489       75.549041   432.719302
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0             0.118400          0.277600        0.300100             0.147100
# 1             0.084740          0.078640        0.086900             0.070170
# 2             0.109600          0.159900        0.197400             0.127900
# 3             0.142500          0.283900        0.241400             0.105200
# 4             0.100300          0.132800        0.198000             0.104300
# ...                ...               ...             ...                  ...
# 10564         0.091204          0.069957        0.024872             0.043946
# 10565         0.145517          0.168273        0.093299             0.081679
# 10566         0.085776          0.102347        0.081731             0.121835
# 10567         0.093984          0.119383        0.117841             0.081529
# 10568         0.069454          0.085861        0.036284             0.030022
#
#        symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0           0.241900  ...     25.380000      17.330000       184.600000
# 1           0.181200  ...     24.990000      23.410000       158.800000
# 2           0.206900  ...     23.570000      25.530000       152.500000
# 3           0.259700  ...     14.910000      26.500000        98.870000
# 4           0.180900  ...     22.540000      16.670000       152.200000
# ...              ...  ...           ...            ...              ...
# 10564       0.226635  ...     13.283847      18.293434        84.709503
# 10565       0.202809  ...     17.090649      28.161669       110.570309
# 10566       0.189788  ...     19.941688      25.303457       129.007313
# 10567       0.193640  ...     22.952756      34.442142       152.119780
# 10568       0.192502  ...     13.058448      25.781170        84.372807
#
#         area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.000000          0.162200           0.665600         0.711900
# 1      1956.000000          0.123800           0.186600         0.241600
# 2      1709.000000          0.144400           0.424500         0.450400
# 3       567.700000          0.209800           0.866300         0.686900
# 4      1575.000000          0.137400           0.205000         0.400000
# ...            ...               ...                ...              ...
# 10564   533.704490          0.119710           0.120541         0.074352
# 10565   897.005786          0.189149           0.363931         0.269874
# 10566  1233.007009          0.102405           0.199145         0.252063
# 10567  1648.030631          0.167075           0.254909         0.242346
# 10568   517.829866          0.142929           0.207678         0.130731
#
#        concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                  0.265400        0.460100                 0.118900
# 1                  0.186000        0.275000                 0.089020
# 2                  0.243000        0.361300                 0.087580
# 3                  0.257500        0.663800                 0.173000
# 4                  0.162500        0.236400                 0.076780
# ...                     ...             ...                      ...
# 10564              0.094832        0.316553                 0.067760
# 10565              0.128229        0.368549                 0.104436
# 10566              0.148563        0.245300                 0.088031
# 10567              0.172600        0.317086                 0.080016
# 10568              0.081839        0.314089                 0.082594
#
# [10569 rows x 31 columns]

# %%
# BOXPLOT FOR EACH COLUMN
plt.figure(figsize = (10,5))
sb.boxplot(data = df)
plt.xticks(rotation = 90)
plt.show()

# %%
# REMOVING OUTLIERS
for i in df.columns:
  q1 = df[i].quantile(0.25)
  q3 = df[i].quantile(0.75)
  iqr = q3 - q1
  upper = q3+1.5*iqr
  lower = q1-1.5*iqr
  df = df[(df[i]>=lower) & (df[i]<=upper)]

# %%
df
# Out:
#        diagnosis  radius_mean  texture_mean  perimeter_mean   area_mean  \
# 10             0    16.020000     23.240000      102.700000  797.800000
# 13             0    15.850000     23.950000      103.700000  782.700000
# 16             0    14.680000     20.130000       94.740000  684.500000
# 19             1    13.540000     14.360000       87.460000  566.300000
# 20             1    13.080000     15.710000       85.630000  520.000000
# ...          ...          ...           ...             ...         ...
# 10558          1    10.284513     12.211957       65.759372  321.607031
# 10561          1    12.776793     16.480369       81.364733  502.532885
# 10562          1    14.553875     13.999717       93.842058  644.180559
# 10564          1    11.760441     14.005757       74.236872  427.301531
# 10568          1    11.832701     17.472489       75.549041  432.719302
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 10            0.082060          0.066690        0.032990             0.033230
# 13            0.084010          0.100200        0.099380             0.053640
# 16            0.098670          0.072000        0.073950             0.052590
# 19            0.097790          0.081290        0.066640             0.047810
# 20            0.107500          0.127000        0.045680             0.031100
# ...                ...               ...             ...                  ...
# 10558         0.128501          0.061814        0.021891             0.028688
# 10561         0.069248          0.051850        0.018340             0.015671
# 10562         0.093898          0.087352        0.054277             0.060880
# 10564         0.091204          0.069957        0.024872             0.043946
# 10568         0.069454          0.085861        0.036284             0.030022
#
#        symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 10          0.152800  ...     19.190000      33.880000       123.800000
# 13          0.184700  ...     16.840000      27.660000       112.000000
# 16          0.158600  ...     19.070000      30.880000       123.400000
# 19          0.188500  ...     15.110000      19.260000        99.700000
# 20          0.196700  ...     14.500000      20.490000        96.090000
# ...              ...  ...           ...            ...              ...
# 10558       0.165353  ...     11.396391      15.661374        73.231887
# 10561       0.185629  ...     13.466379      19.730231        85.650495
# 10562       0.143069  ...     15.820547      16.928063       103.147150
# 10564       0.226635  ...     13.283847      18.293434        84.709503
# 10568       0.192502  ...     13.058448      25.781170        84.372807
#
#         area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 10     1150.000000          0.118100           0.155100         0.145900
# 13      876.500000          0.113100           0.192400         0.232200
# 16     1138.000000          0.146400           0.187100         0.291400
# 19      711.200000          0.144000           0.177300         0.239000
# 20      630.500000          0.131200           0.277600         0.189000
# ...            ...               ...                ...              ...
# 10558   394.491613          0.134016           0.176324         0.082919
# 10561   554.903124          0.177691           0.060994         0.107850
# 10562   749.905027          0.144354           0.129313         0.149522
# 10564   533.704490          0.119710           0.120541         0.074352
# 10568   517.829866          0.142929           0.207678         0.130731
#
#        concave points_worst  symmetry_worst  fractal_dimension_worst
# 10                 0.099750        0.294800                 0.084520
# 13                 0.111900        0.280900                 0.062870
# 16                 0.160900        0.302900                 0.082160
# 19                 0.128800        0.297700                 0.072590
# 20                 0.072830        0.318400                 0.081830
# ...                     ...             ...                      ...
# 10558              0.083014        0.257791                 0.074818
# 10561              0.079909        0.230693                 0.084208
# 10562              0.111672        0.245687                 0.081479
# 10564              0.094832        0.316553                 0.067760
# 10568              0.081839        0.314089                 0.082594
#
# [5831 rows x 31 columns]

# %%
# BOXPLOT FOR EACH COLUMN
plt.figure(figsize = (10,5))
sb.boxplot(data = df)
plt.xticks(rotation = 90)
plt.show()

# %%
# SCATTERPLOT FOR EACH COLUMN
plt.figure(figsize = (10,5))
sb.scatterplot(data = df)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# DIVIDING DATASET INTO X AND Y
x=df.drop('diagnosis',axis=1)
x
# Out:
#        radius_mean  texture_mean  perimeter_mean   area_mean  smoothness_mean  \
# 10       16.020000     23.240000      102.700000  797.800000         0.082060
# 13       15.850000     23.950000      103.700000  782.700000         0.084010
# 16       14.680000     20.130000       94.740000  684.500000         0.098670
# 19       13.540000     14.360000       87.460000  566.300000         0.097790
# 20       13.080000     15.710000       85.630000  520.000000         0.107500
# ...            ...           ...             ...         ...              ...
# 10558    10.284513     12.211957       65.759372  321.607031         0.128501
# 10561    12.776793     16.480369       81.364733  502.532885         0.069248
# 10562    14.553875     13.999717       93.842058  644.180559         0.093898
# 10564    11.760441     14.005757       74.236872  427.301531         0.091204
# 10568    11.832701     17.472489       75.549041  432.719302         0.069454
#
#        compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 10             0.066690        0.032990             0.033230       0.152800
# 13             0.100200        0.099380             0.053640       0.184700
# 16             0.072000        0.073950             0.052590       0.158600
# 19             0.081290        0.066640             0.047810       0.188500
# 20             0.127000        0.045680             0.031100       0.196700
# ...                 ...             ...                  ...            ...
# 10558          0.061814        0.021891             0.028688       0.165353
# 10561          0.051850        0.018340             0.015671       0.185629
# 10562          0.087352        0.054277             0.060880       0.143069
# 10564          0.069957        0.024872             0.043946       0.226635
# 10568          0.085861        0.036284             0.030022       0.192502
#
#        fractal_dimension_mean  ...  radius_worst  texture_worst  \
# 10                   0.056970  ...     19.190000      33.880000
# 13                   0.053380  ...     16.840000      27.660000
# 16                   0.059220  ...     19.070000      30.880000
# 19                   0.057660  ...     15.110000      19.260000
# 20                   0.068110  ...     14.500000      20.490000
# ...                       ...  ...           ...            ...
# 10558                0.107042  ...     11.396391      15.661374
# 10561                0.045345  ...     13.466379      19.730231
# 10562                0.043009  ...     15.820547      16.928063
# 10564                0.073488  ...     13.283847      18.293434
# 10568                0.068729  ...     13.058448      25.781170
#
#        perimeter_worst   area_worst  smoothness_worst  compactness_worst  \
# 10          123.800000  1150.000000          0.118100           0.155100
# 13          112.000000   876.500000          0.113100           0.192400
# 16          123.400000  1138.000000          0.146400           0.187100
# 19           99.700000   711.200000          0.144000           0.177300
# 20           96.090000   630.500000          0.131200           0.277600
# ...                ...          ...               ...                ...
# 10558        73.231887   394.491613          0.134016           0.176324
# 10561        85.650495   554.903124          0.177691           0.060994
# 10562       103.147150   749.905027          0.144354           0.129313
# 10564        84.709503   533.704490          0.119710           0.120541
# 10568        84.372807   517.829866          0.142929           0.207678
#
#        concavity_worst  concave points_worst  symmetry_worst  \
# 10            0.145900              0.099750        0.294800
# 13            0.232200              0.111900        0.280900
# 16            0.291400              0.160900        0.302900
# 19            0.239000              0.128800        0.297700
# 20            0.189000              0.072830        0.318400
# ...                ...                   ...             ...
# 10558         0.082919              0.083014        0.257791
# 10561         0.107850              0.079909        0.230693
# 10562         0.149522              0.111672        0.245687
# 10564         0.074352              0.094832        0.316553
# 10568         0.130731              0.081839        0.314089
#
#        fractal_dimension_worst
# 10                    0.084520
# 13                    0.062870
# 16                    0.082160
# 19                    0.072590
# 20                    0.081830
# ...                        ...
# 10558                 0.074818
# 10561                 0.084208
# 10562                 0.081479
# 10564                 0.067760
# 10568                 0.082594
#
# [5831 rows x 30 columns]

# %%
# DIVIDING DATASET INTO X AND Y
y=df['diagnosis']
y
# Out:
# 10       0
# 13       0
# 16       0
# 19       1
# 20       1
#         ..
# 10558    1
# 10561    1
# 10562    1
# 10564    1
# 10568    1
# Name: diagnosis, Length: 5831, dtype: int64

# %% [markdown]
# ### LOGISTIC REGRESSION

# %%
# TRAIN TEST SPLIT
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 42)

# %%
x_train
# Out:
#       radius_mean  texture_mean  perimeter_mean   area_mean  smoothness_mean  \
# 5502     9.836413     19.403037       63.934236  298.307638         0.129478
# 3103    14.607694     15.730956       92.709183  664.880383         0.078710
# 6012    12.915695     15.916576       83.716117  512.222441         0.061940
# 428     11.130000     16.620000       70.470000  381.100000         0.081510
# 570      8.582595     20.997321       54.642877  221.766861         0.138132
# ...           ...           ...             ...         ...              ...
# 6793    14.721292     25.426900       94.727468  668.600409         0.093708
# 9420    11.332835     14.140101       71.777153  396.613221         0.102901
# 9490    14.293545     22.533964       93.760524  629.822257         0.079700
# 9759    13.870303     16.202620       88.503429  593.706457         0.087894
# 1487    14.349013     13.489037       92.513056  641.209594         0.105579
#
#       compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 5502          0.062000        0.057321             0.027121       0.190063
# 3103          0.035140        0.027307             0.064916       0.130371
# 6012          0.086183        0.070565             0.071514       0.187679
# 428           0.038340        0.013690             0.013700       0.151100
# 570           0.098527        0.043448            -0.001052       0.181622
# ...                ...             ...                  ...            ...
# 6793          0.107810        0.041323             0.009116       0.166564
# 9420          0.001175        0.040786             0.003080       0.196017
# 9490          0.123187        0.131855             0.083943       0.193263
# 9759          0.055143       -0.015163             0.051805       0.160678
# 1487          0.083548        0.014130             0.046161       0.180019
#
#       fractal_dimension_mean  ...  radius_worst  texture_worst  \
# 5502                0.073187  ...     10.782872      26.832991
# 3103                0.066251  ...     16.465772      21.729160
# 6012                0.063132  ...     14.464809      21.828019
# 428                 0.061480  ...     11.680000      20.290000
# 570                 0.066654  ...      9.558344      27.051742
# ...                      ...  ...           ...            ...
# 6793                0.072881  ...     16.481730      32.303855
# 9420                0.019613  ...     12.218174      18.967717
# 9490                0.067467  ...     15.289477      34.296696
# 9759                0.064986  ...     15.080547      25.574840
# 1487                0.064216  ...     16.775368      16.906781
#
#       perimeter_worst  area_worst  smoothness_worst  compactness_worst  \
# 5502        72.215076  361.210297          0.156779           0.222206
# 3103       103.719645  840.796426          0.086774           0.089204
# 6012        97.150802  643.801983          0.149654           0.243571
# 428         74.350000  421.100000          0.103000           0.062190
# 570         62.048174  273.865359          0.198945           0.168056
# ...               ...         ...               ...                ...
# 6793       107.413341  826.415968          0.133418           0.120496
# 9420        77.387493  458.008412          0.122142           0.062423
# 9490       104.307932  728.332134          0.109917           0.227608
# 9759        96.728009  694.379918          0.121303           0.107685
# 1487       110.408065  873.187647          0.149016           0.122722
#
#       concavity_worst  concave points_worst  symmetry_worst  \
# 5502         0.242501              0.077323        0.298780
# 3103         0.005538              0.036614        0.247901
# 6012         0.227811              0.121567        0.331725
# 428          0.045800              0.040440        0.238300
# 570          0.076733              0.055137        0.305673
# ...               ...                   ...             ...
# 6793         0.187655              0.106007        0.269719
# 9420         0.002378              0.030129        0.318224
# 9490         0.413858              0.130696        0.289555
# 9759         0.080812              0.049096        0.249744
# 1487         0.162879              0.084923        0.304786
#
#       fractal_dimension_worst
# 5502                 0.103383
# 3103                 0.051576
# 6012                 0.093127
# 428                  0.070830
# 570                  0.093977
# ...                       ...
# 6793                 0.099822
# 9420                 0.074100
# 9490                 0.046738
# 9759                 0.076048
# 1487                 0.095281
#
# [4664 rows x 30 columns]

# %%
y_train
# Out:
# 5502    1
# 3103    1
# 6012    1
# 428     1
# 570     1
#        ..
# 6793    1
# 9420    1
# 9490    0
# 9759    1
# 1487    1
# Name: diagnosis, Length: 4664, dtype: int64

# %%
# BUILDING THE LOGISTIC REGRESSION MODEL
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# PREDICTION BY THE MODEL
y_pred = lr.predict(x_test)
y_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
# DETERMINING ACCURACY OF THE MODEL
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
a = confusion_matrix(y_test,y_pred)
print("Accuracy Score : ", (accuracy_score(y_test,y_pred)*100))
print(classification_report(y_test,y_pred))
print(sb.heatmap(a,annot=True))
# Out:
# Accuracy Score :  97.34361610968296
#               precision    recall  f1-score   support
#
#            0       0.91      0.79      0.85       108
#            1       0.98      0.99      0.99      1059
#
#     accuracy                           0.97      1167
#    macro avg       0.95      0.89      0.92      1167
# weighted avg       0.97      0.97      0.97      1167
#
# Axes(0.125,0.11;0.62x0.77)

# %% [markdown]
# ### MULTI CLASSIFICATION

# %%
# HEATMAP OF THE DATASET
plt.figure(figsize = (10,5))
sb.heatmap(df.corr(),annot = True)
plt.show()

# %%
# DIVIDING DATASET INTO X AND Y
x=df.drop('diagnosis',axis=1)
x
# Out:
#        radius_mean  texture_mean  perimeter_mean   area_mean  smoothness_mean  \
# 10       16.020000     23.240000      102.700000  797.800000         0.082060
# 13       15.850000     23.950000      103.700000  782.700000         0.084010
# 16       14.680000     20.130000       94.740000  684.500000         0.098670
# 19       13.540000     14.360000       87.460000  566.300000         0.097790
# 20       13.080000     15.710000       85.630000  520.000000         0.107500
# ...            ...           ...             ...         ...              ...
# 10558    10.284513     12.211957       65.759372  321.607031         0.128501
# 10561    12.776793     16.480369       81.364733  502.532885         0.069248
# 10562    14.553875     13.999717       93.842058  644.180559         0.093898
# 10564    11.760441     14.005757       74.236872  427.301531         0.091204
# 10568    11.832701     17.472489       75.549041  432.719302         0.069454
#
#        compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 10             0.066690        0.032990             0.033230       0.152800
# 13             0.100200        0.099380             0.053640       0.184700
# 16             0.072000        0.073950             0.052590       0.158600
# 19             0.081290        0.066640             0.047810       0.188500
# 20             0.127000        0.045680             0.031100       0.196700
# ...                 ...             ...                  ...            ...
# 10558          0.061814        0.021891             0.028688       0.165353
# 10561          0.051850        0.018340             0.015671       0.185629
# 10562          0.087352        0.054277             0.060880       0.143069
# 10564          0.069957        0.024872             0.043946       0.226635
# 10568          0.085861        0.036284             0.030022       0.192502
#
#        fractal_dimension_mean  ...  radius_worst  texture_worst  \
# 10                   0.056970  ...     19.190000      33.880000
# 13                   0.053380  ...     16.840000      27.660000
# 16                   0.059220  ...     19.070000      30.880000
# 19                   0.057660  ...     15.110000      19.260000
# 20                   0.068110  ...     14.500000      20.490000
# ...                       ...  ...           ...            ...
# 10558                0.107042  ...     11.396391      15.661374
# 10561                0.045345  ...     13.466379      19.730231
# 10562                0.043009  ...     15.820547      16.928063
# 10564                0.073488  ...     13.283847      18.293434
# 10568                0.068729  ...     13.058448      25.781170
#
#        perimeter_worst   area_worst  smoothness_worst  compactness_worst  \
# 10          123.800000  1150.000000          0.118100           0.155100
# 13          112.000000   876.500000          0.113100           0.192400
# 16          123.400000  1138.000000          0.146400           0.187100
# 19           99.700000   711.200000          0.144000           0.177300
# 20           96.090000   630.500000          0.131200           0.277600
# ...                ...          ...               ...                ...
# 10558        73.231887   394.491613          0.134016           0.176324
# 10561        85.650495   554.903124          0.177691           0.060994
# 10562       103.147150   749.905027          0.144354           0.129313
# 10564        84.709503   533.704490          0.119710           0.120541
# 10568        84.372807   517.829866          0.142929           0.207678
#
#        concavity_worst  concave points_worst  symmetry_worst  \
# 10            0.145900              0.099750        0.294800
# 13            0.232200              0.111900        0.280900
# 16            0.291400              0.160900        0.302900
# 19            0.239000              0.128800        0.297700
# 20            0.189000              0.072830        0.318400
# ...                ...                   ...             ...
# 10558         0.082919              0.083014        0.257791
# 10561         0.107850              0.079909        0.230693
# 10562         0.149522              0.111672        0.245687
# 10564         0.074352              0.094832        0.316553
# 10568         0.130731              0.081839        0.314089
#
#        fractal_dimension_worst
# 10                    0.084520
# 13                    0.062870
# 16                    0.082160
# 19                    0.072590
# 20                    0.081830
# ...                        ...
# 10558                 0.074818
# 10561                 0.084208
# 10562                 0.081479
# 10564                 0.067760
# 10568                 0.082594
#
# [5831 rows x 30 columns]

# %%
# DIVIDING DATASET INTO X AND Y
y=df['diagnosis']
y
# Out:
# 10       0
# 13       0
# 16       0
# 19       1
# 20       1
#         ..
# 10558    1
# 10561    1
# 10562    1
# 10564    1
# 10568    1
# Name: diagnosis, Length: 5831, dtype: int64

# %%
# TRAIN TEST SPLIT
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 42)

# %%
# BUILDING THE LOGISTIC REGRESSION MODEL
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# PREDICTION BY THE MODEL
y_pred = lr.predict(x_test)
y_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
# DETERMINING ACCURACY OF THE MODEL
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,precision_score,recall_score,f1_score
a = confusion_matrix(y_test,y_pred)
mc_accuracy = (accuracy_score(y_test,y_pred)*100)
mc_precision = precision_score(y_test,y_pred,average='micro')
mc_recall = recall_score(y_test,y_pred,average='micro')
mc_f1 = f1_score(y_test,y_pred,average='micro')
print("Accuracy Score : ", accuracy_score(y_test,y_pred)*100)
print(classification_report(y_test,y_pred))
print(sb.heatmap(a,annot=True))
# Out:
# Accuracy Score :  97.34361610968296
#               precision    recall  f1-score   support
#
#            0       0.91      0.79      0.85       108
#            1       0.98      0.99      0.99      1059
#
#     accuracy                           0.97      1167
#    macro avg       0.95      0.89      0.92      1167
# weighted avg       0.97      0.97      0.97      1167
#
# Axes(0.125,0.11;0.62x0.77)

# %% [markdown]
# ### DECISION TREE CLASSIFIER

# %%
# PREDICTION BY THE MODEL
from sklearn.tree import DecisionTreeClassifier
treemodel = DecisionTreeClassifier()
treemodel.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
# PLOTTING THE DECISION TREE OF THE DATASET
from sklearn import tree
plt.figure(figsize = (15,10))
tree.plot_tree(treemodel,filled = True)
plt.show()

# %%
# PREDICTION BY THE MODEL
y_pred = treemodel.predict(x_test)
y_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
# DETERMINING ACCURACY OF THE MODEL
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
a = confusion_matrix(y_test,y_pred,)
dtc_accuracy = (accuracy_score(y_test,y_pred)*100)
dtc_precision = precision_score(y_test,y_pred,average='micro')
dtc_recall = recall_score(y_test,y_pred,average='micro')
dtc_f1 = f1_score(y_test,y_pred,average='micro')
print(accuracy_score(y_test,y_pred))
print("Accuracy Score : ", accuracy_score(y_test,y_pred)*100)
print(classification_report(y_test,y_pred))
print(sb.heatmap(a,annot=True))
# Out:
# 0.9991431019708654
# Accuracy Score :  99.91431019708654
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00       108
#            1       1.00      1.00      1.00      1059
#
#     accuracy                           1.00      1167
#    macro avg       1.00      1.00      1.00      1167
# weighted avg       1.00      1.00      1.00      1167
#
# Axes(0.125,0.11;0.62x0.77)

# %% [markdown]
# ### RANDOM FOREST CLASSIFER

# %%
# BUILDING THE RANDOM FOREST MODEL
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=50,random_state = 42)
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=50, random_state=42)

# %%
# PREDICTION BY THE MODEL
y_pred=rf.predict(x_test)
y_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
# DETERMINING ACCURACY OF THE MODEL
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
a = confusion_matrix(y_test,y_pred)
rfc_accuracy = (accuracy_score(y_test,y_pred)*100)
rfc_precision = precision_score(y_test,y_pred,average='micro')
rfc_recall = recall_score(y_test,y_pred,average='micro')
rfc_f1 = f1_score(y_test,y_pred,average='micro')
print(accuracy_score(y_test,y_pred))
print(sb.heatmap(a,annot = True))
print(classification_report(y_test,y_pred))
# Out:
# 1.0
# Axes(0.125,0.11;0.62x0.77)
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       108
#            1       1.00      1.00      1.00      1059
#
#     accuracy                           1.00      1167
#    macro avg       1.00      1.00      1.00      1167
# weighted avg       1.00      1.00      1.00      1167

# %% [markdown]
# ### K-NEAREST NEIGHBORS

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
# DETERMINING ACCURACY OF THE MODEL
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,precision_score,recall_score,f1_score
y_pred = knn.predict(x_test)
knn_accuracy =( accuracy_score(y_test,y_pred) *100)
knn_precision = precision_score(y_test,y_pred,average='micro')
knn_recall = recall_score(y_test,y_pred,average='micro')
knn_f1 = f1_score(y_test,y_pred,average='micro')
print("ACCURACY SCORE : ", knn_accuracy)
print(sb.heatmap(confusion_matrix(y_test,y_pred),annot = True))
print(classification_report(y_test,y_pred))
# Out:
# ACCURACY SCORE :  100.0
# Axes(0.125,0.11;0.62x0.77)
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       108
#            1       1.00      1.00      1.00      1059
#
#     accuracy                           1.00      1167
#    macro avg       1.00      1.00      1.00      1167
# weighted avg       1.00      1.00      1.00      1167

# %% [markdown]
# ### NAIVE BAYES

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()

#fitting-
gnb.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
#predicting
y_pred=gnb.predict(x_test)
y_pred
# Out:
# array([1, 1, 0, ..., 0, 1, 1])

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
y_pred = gnb.predict(x_test)
nvb_accuracy = (accuracy_score(y_test,y_pred)*100)
nvb_precision = precision_score(y_test,y_pred,average='micro')
nvb_recall = recall_score(y_test,y_pred,average='micro')
nvb_f1 = f1_score(y_test,y_pred,average='micro')
print("ACCURACY SCORE : ", nvb_accuracy)
print(sb.heatmap(confusion_matrix(y_test,y_pred),annot = True))
print(classification_report(y_test,y_pred))
# Out:
# ACCURACY SCORE :  88.2604970008569
# Axes(0.125,0.11;0.62x0.77)
#               precision    recall  f1-score   support
#
#            0       0.44      0.94      0.60       108
#            1       0.99      0.88      0.93      1059
#
#     accuracy                           0.88      1167
#    macro avg       0.71      0.91      0.76      1167
# weighted avg       0.94      0.88      0.90      1167

# %% [markdown]
# ### COMPARISONS

# %%
a = pd.DataFrame({'Model' : ['Logistic Regression','Decision Tree','Random Forest','KNN','Naive Bayes'],
                  'Accuracy' : [mc_accuracy,dtc_accuracy,rfc_accuracy,knn_accuracy,nvb_accuracy],
                  'Precision' : [mc_precision,dtc_precision,rfc_precision,knn_precision,nvb_precision],
                  'Recall' : [mc_recall,dtc_recall,rfc_recall,knn_recall,nvb_recall],
                  'F-1 Score' : [mc_f1,dtc_f1,rfc_f1,knn_f1,nvb_f1]})

a.style.set_table_styles([{'selector' : '',
                            'props' : [('border',
                                        '1px solid black')]}])
# Out:
# <style type="text/css">
# #T_c558e  {
#   border: 1px solid black;
# }
# </style>
# <table id="T_c558e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c558e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_c558e_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_c558e_level0_col2" class="col_heading level0 col2" >Precision</th>
#       <th id="T_c558e_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_c558e_level0_col4" class="col_heading level0 col4" >F-1 Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c558e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c558e_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_c558e_row0_col1" class="data row0 col1" >97.343616</td>
#       <td id="T_c558e_row0_col2" class="data row0 col2" >0.973436</td>
#       <td id="T_c558e_row0_col3" class="data row0 col3" >0.973436</td>
#       <td id="T_c558e_row0_col4" class="data row0 col4" >0.973436</td>
#     </tr>
#     <tr>
#       <th id="T_c558e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c558e_row1_col0" class="data row1 col0" >Decision Tree</td>
#       <td id="T_c558e_row1_col1" class="data row1 col1" >99.914310</td>
#       <td id="T_c558e_row1_col2" class="data row1 col2" >0.999143</td>
#       <td id="T_c558e_row1_col3" class="data row1 col3" >0.999143</td>
#       <td id="T_c558e_row1_col4" class="data row1 col4" >0.999143</td>
#     </tr>
#     <tr>
#       <th id="T_c558e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c558e_row2_col0" class="data row2 col0" >Random Forest</td>
#       <td id="T_c558e_row2_col1" class="data row2 col1" >100.000000</td>
#       <td id="T_c558e_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_c558e_row2_col3" class="data row2 col3" >1.000000</td>
#       <td id="T_c558e_row2_col4" class="data row2 col4" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c558e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c558e_row3_col0" class="data row3 col0" >KNN</td>
#       <td id="T_c558e_row3_col1" class="data row3 col1" >100.000000</td>
#       <td id="T_c558e_row3_col2" class="data row3 col2" >1.000000</td>
#       <td id="T_c558e_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_c558e_row3_col4" class="data row3 col4" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c558e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c558e_row4_col0" class="data row4 col0" >Naive Bayes</td>
#       <td id="T_c558e_row4_col1" class="data row4 col1" >88.260497</td>
#       <td id="T_c558e_row4_col2" class="data row4 col2" >0.882605</td>
#       <td id="T_c558e_row4_col3" class="data row4 col3" >0.882605</td>
#       <td id="T_c558e_row4_col4" class="data row4 col4" >0.882605</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.figure(figsize = (10,5))
plt.xlabel("Models")
plt.ylabel("Accuracy")
plt.title("Model Accuracy")
plt.bar_label(plt.bar(a['Model'],a['Accuracy']))
plt.bar(a['Model'],a['Accuracy'],color = ['r','g','b','y','c'])
plt.show()

# %%
y_test
# Out:
# 8070    1
# 9616    1
# 1955    1
# 939     1
# 2076    1
#        ..
# 8025    1
# 2995    1
# 8397    1
# 2895    1
# 8674    1
# Name: diagnosis, Length: 1167, dtype: int64

# %%
plt.bar(y_test,y_pred)
plt.show()
